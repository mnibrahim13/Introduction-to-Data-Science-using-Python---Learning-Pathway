# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv(r'E:\NED Office\Courses\Fall 2024\PITP - Data Science\Datasets\imdb-top-1000.csv')

# %%
movies.shape
# Out:
# (1000, 10)

# %%
movies.describe()
# Out:
#            Runtime  IMDB_Rating   No_of_Votes         Gross   Metascore
# count  1000.000000  1000.000000  1.000000e+03  1.000000e+03  843.000000
# mean    122.891000     7.949300  2.736929e+05  1.282781e+08   77.971530
# std      28.093671     0.275491  3.273727e+05  2.011110e+08   12.376099
# min      45.000000     7.600000  2.508800e+04  1.305000e+03   28.000000
# 25%     103.000000     7.700000  5.552625e+04  5.012919e+06   70.000000
# 50%     119.000000     7.900000  1.385485e+05  3.953432e+07   79.000000
# 75%     137.000000     8.100000  3.741612e+05  1.615997e+08   87.000000
# max     321.000000     9.300000  2.343110e+06  9.366622e+08  100.000000

# %% [markdown]
# - Runtime: Most movies have a runtime between 103 and 137 minutes, with a few extreme cases as high as 321 minutes.
# - IMDB Rating: The ratings are high overall, with a tight range (7.6 to 9.3), indicating a selection of well-liked movies.
# - Number of Votes: The number of votes varies greatly, from 25,088 to over 2 million, showing significant differences in popularity.
# - Gross Revenue: There is a large disparity in gross revenue, with most movies earning under $161 million, but some making over $936 million.

# %%
movies.describe(include='all')
# Out:
#        Series_Title Released_Year      Runtime  Genre  IMDB_Rating  \
# count          1000          1000  1000.000000   1000  1000.000000
# unique          999           100          NaN     14          NaN
# top        Drishyam          2014          NaN  Drama          NaN
# freq              2            32          NaN    289          NaN
# mean            NaN           NaN   122.891000    NaN     7.949300
# std             NaN           NaN    28.093671    NaN     0.275491
# min             NaN           NaN    45.000000    NaN     7.600000
# 25%             NaN           NaN   103.000000    NaN     7.700000
# 50%             NaN           NaN   119.000000    NaN     7.900000
# 75%             NaN           NaN   137.000000    NaN     8.100000
# max             NaN           NaN   321.000000    NaN     9.300000
#
#                 Director      Star1   No_of_Votes         Gross   Metascore
# count               1000       1000  1.000000e+03  1.000000e+03  843.000000
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   1000 non-null   object
#  1   Released_Year  1000 non-null   object
#  2   Runtime        1000 non-null   int64
#  3   Genre          1000 non-null   object
#  4   IMDB_Rating    1000 non-null   float64
#  5   Director       1000 non-null   object
#  6   Star1          1000 non-null   object
#  7   No_of_Votes    1000 non-null   int64
#  8   Gross          1000 non-null   float64
#  9   Metascore      843 non-null    float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 78.3+ KB

# %%
movies
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
movies.head()
# Out:
#                Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142   Drama          9.3
# 1             The Godfather          1972      175   Crime          9.2
# 2           The Dark Knight          2008      152  Action          9.0
# 3    The Godfather: Part II          1974      202   Crime          9.0
# 4              12 Angry Men          1957       96   Crime          9.0
#
#                Director           Star1  No_of_Votes        Gross  Metascore
# 0        Frank Darabont     Tim Robbins      2343110   28341469.0       80.0
# 1  Francis Ford Coppola   Marlon Brando      1620367  134966411.0      100.0
# 2     Christopher Nolan  Christian Bale      2303232  534858444.0       84.0
# 3  Francis Ford Coppola       Al Pacino      1129952   57300000.0       90.0
# 4          Sidney Lumet     Henry Fonda       689845    4360000.0       96.0

# %%
movies.tail()
# Out:
#                Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 995  Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                   Giant          1956      201   Drama          7.6
# 997   From Here to Eternity          1953      118   Drama          7.6
# 998                Lifeboat          1944       97   Drama          7.6
# 999            The 39 Steps          1935       86   Crime          7.6
#
#              Director              Star1  No_of_Votes        Gross  Metascore
# 995     Blake Edwards     Audrey Hepburn       166544  679874270.0       76.0
# 996    George Stevens   Elizabeth Taylor        34075  195217415.0       84.0
# 997    Fred Zinnemann     Burt Lancaster        43374   30500000.0       85.0
# 998  Alfred Hitchcock  Tallulah Bankhead        26471  852142728.0       78.0
# 999  Alfred Hitchcock       Robert Donat        51853  302787539.0       93.0

# %%
movies.columns
# Out:
# Index(['Series_Title', 'Released_Year', 'Runtime', 'Genre', 'IMDB_Rating',
#        'Director', 'Star1', 'No_of_Votes', 'Gross', 'Metascore'],
#       dtype='object')

# %%
# All movies released in 2014

movies[movies['Released_Year'] == 2014]
# Out:
# Empty DataFrame
# Columns: [Series_Title, Released_Year, Runtime, Genre, IMDB_Rating, Director, Star1, No_of_Votes, Gross, Metascore]
# Index: []

# %%
# All movies released in 2014

movies[movies['Released_Year'] == '2014']
# Out:
#                                         Series_Title Released_Year  Runtime  \
# 21                                      Interstellar          2014      169
# 34                                          Whiplash          2014      106
# 200                                            Mommy          2014      139
# 201                                           Haider          2014      160
# 204                                 Relatos salvajes          2014      122
# 206                                       Kis Uykusu          2014      196
# 207                                               PK          2014      153
# 209                         The Grand Budapest Hotel          2014       99
# 210                                        Gone Girl          2014      149
# 219                                  Song of the Sea          2014       93
# 337                         Serbuan maut 2: Berandal          2014      150
# ...

# %%
# count of movies released in 2014

movies[movies['Released_Year'] == '2014'].shape
# Out:
# (32, 10)

# %%
# Count of movies released each year

movies['Released_Year'].value_counts()
# Out:
# Released_Year
# 2014    32
# 2004    31
# 2009    29
# 2013    28
# 2016    28
#         ..
# 1926     1
# 1936     1
# 1924     1
# 1921     1
# PG       1
# Name: count, Length: 100, dtype: int64

# %%
# Unique values of Released_Year

movies['Released_Year'].unique()
# Out:
# array(['1994', '1972', '2008', '1974', '1957', '2003', '1993', '2010',
#        '1999', '2001', '1966', '2002', '1990', '1980', '1975', '2020',
#        '2019', '2014', '1998', '1997', '1995', '1991', '1977', '1962',
#        '1954', '1946', '2011', '2006', '2000', '1988', '1985', '1968',
#        '1960', '1942', '1936', '1931', '2018', '2017', '2016', '2012',
#        '2009', '2007', '1984', '1981', '1979', '1971', '1963', '1964',
#        '1950', '1940', '2013', '2005', '2004', '1992', '1987', '1986',
#        '1983', '1976', '1973', '1965', '1959', '1958', '1952', '1948',
#        '1944', '1941', '1927', '1921', '2015', '1996', '1989', '1978',
#        '1961', '1955', '1953', '1925', '1924', '1982', '1967', '1951',
#        '1949', '1939', '1937', '1934', '1928', '1926', '1920', '1970',
#        '1969', '1956', '1947', '1945', '1930', '1938', '1935', '1933',
#        '1932', '1922', '1943', 'PG'], dtype=object)

# %%
# Count of unique values of Released_Year

movies['Released_Year'].nunique()
# Out:
# 100

# %% [markdown]
# ## Practice with Other columns

# %% [markdown]
# # Data preprocessing
#
# It is a crucial step in the machine learning pipeline, as the quality of the data greatly impacts the performance of models. Preprocessing involves cleaning, transforming, and encoding data to ensure it is suitable for analysis or machine learning.
#
# The key steps in data preprocessing include:
# - Handling missing data
# - Handling duplicated data
# - Feature scaling
# - Encoding categorical variables
# - Handling outliers

# %%
movies
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %% [markdown]
# #### Handling Missing Data
#
# Real-world datasets often contain missing values, which can impact model performance. There are several techniques to handle missing data:
# - **Dropping Missing Values**: Remove rows or columns with missing data.
# - **Imputing Missing Values**: Replace missing values using statistical measures such as mean, median, or mode.

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   1000 non-null   object
#  1   Released_Year  1000 non-null   object
#  2   Runtime        1000 non-null   int64
#  3   Genre          1000 non-null   object
#  4   IMDB_Rating    1000 non-null   float64
#  5   Director       1000 non-null   object
#  6   Star1          1000 non-null   object
#  7   No_of_Votes    1000 non-null   int64
#  8   Gross          1000 non-null   float64
#  9   Metascore      843 non-null    float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 78.3+ KB

# %% [markdown]
# - .isna() and .isnull(): Both are used to detect missing values (NaNs) in the data and return True for missing values.
# - .notna() and .notnull(): Both are used to detect non-missing values and return True for values that exist.

# %%
movies.isna()
# Out:
#      Series_Title  Released_Year  Runtime  Genre  IMDB_Rating  Director  \
# 0           False          False    False  False        False     False
# 1           False          False    False  False        False     False
# 2           False          False    False  False        False     False
# 3           False          False    False  False        False     False
# 4           False          False    False  False        False     False
# ..            ...            ...      ...    ...          ...       ...
# 995         False          False    False  False        False     False
# 996         False          False    False  False        False     False
# 997         False          False    False  False        False     False
# 998         False          False    False  False        False     False
# 999         False          False    False  False        False     False
#
#      Star1  No_of_Votes  Gross  Metascore
# 0    False        False  False      False
# ...

# %%
movies.notna()
# Out:
#      Series_Title  Released_Year  Runtime  Genre  IMDB_Rating  Director  \
# 0            True           True     True   True         True      True
# 1            True           True     True   True         True      True
# 2            True           True     True   True         True      True
# 3            True           True     True   True         True      True
# 4            True           True     True   True         True      True
# ..            ...            ...      ...    ...          ...       ...
# 995          True           True     True   True         True      True
# 996          True           True     True   True         True      True
# 997          True           True     True   True         True      True
# 998          True           True     True   True         True      True
# 999          True           True     True   True         True      True
#
#      Star1  No_of_Votes  Gross  Metascore
# 0     True         True   True       True
# ...

# %%
movies.isnull()
# Out:
#      Series_Title  Released_Year  Runtime  Genre  IMDB_Rating  Director  \
# 0           False          False    False  False        False     False
# 1           False          False    False  False        False     False
# 2           False          False    False  False        False     False
# 3           False          False    False  False        False     False
# 4           False          False    False  False        False     False
# ..            ...            ...      ...    ...          ...       ...
# 995         False          False    False  False        False     False
# 996         False          False    False  False        False     False
# 997         False          False    False  False        False     False
# 998         False          False    False  False        False     False
# 999         False          False    False  False        False     False
#
#      Star1  No_of_Votes  Gross  Metascore
# 0    False        False  False      False
# ...

# %%
movies.notnull()
# Out:
#      Series_Title  Released_Year  Runtime  Genre  IMDB_Rating  Director  \
# 0            True           True     True   True         True      True
# 1            True           True     True   True         True      True
# 2            True           True     True   True         True      True
# 3            True           True     True   True         True      True
# 4            True           True     True   True         True      True
# ..            ...            ...      ...    ...          ...       ...
# 995          True           True     True   True         True      True
# 996          True           True     True   True         True      True
# 997          True           True     True   True         True      True
# 998          True           True     True   True         True      True
# 999          True           True     True   True         True      True
#
#      Star1  No_of_Votes  Gross  Metascore
# 0     True         True   True       True
# ...

# %% [markdown]
# Now use it with .sum()

# %%
movies.dropna()
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
movies
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
movies.dropna(inplace=True)
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 843 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   843 non-null    object
#  1   Released_Year  843 non-null    object
#  2   Runtime        843 non-null    int64
#  3   Genre          843 non-null    object
#  4   IMDB_Rating    843 non-null    float64
#  5   Director       843 non-null    object
#  6   Star1          843 non-null    object
#  7   No_of_Votes    843 non-null    int64
#  8   Gross          843 non-null    float64
#  9   Metascore      843 non-null    float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 72.4+ KB

# %%
movies.duplicated().sum()
# Out:
# 0

# %%
movies.drop_duplicates()
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
movies.drop_duplicates(inplace=True)
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 843 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   843 non-null    object
#  1   Released_Year  843 non-null    object
#  2   Runtime        843 non-null    int64
#  3   Genre          843 non-null    object
#  4   IMDB_Rating    843 non-null    float64
#  5   Director       843 non-null    object
#  6   Star1          843 non-null    object
#  7   No_of_Votes    843 non-null    int64
#  8   Gross          843 non-null    float64
#  9   Metascore      843 non-null    float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 72.4+ KB
